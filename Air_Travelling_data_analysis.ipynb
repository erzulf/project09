# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
data=pd.read_csv('C://Users//samsung//Desktop//air travel dataset.csv')

# %%
data.shape
# Out:
# (88532, 17)

# %%
data.head()
# Out:
#    Geometry Coordinates 0 0  Geometry Coordinates 0 1  \
# 0               -122.370943                  37.61799
# 1               -122.370943                  37.61799
# 2               -122.370943                  37.61799
# 3               -122.370943                  37.61799
# 4               -122.370943                  37.61799
#
#    Geometry Coordinates 1 0  Geometry Coordinates 1 1 Geometry Type  \
# 0               -118.353322                 34.196704    MultiPoint
# 1               -118.353322                 34.196704    MultiPoint
# 2               -118.353322                 34.196704    MultiPoint
# 3               -118.353322                 34.196704    MultiPoint
# 4               -118.353322                 34.196704    MultiPoint
#
#   Properties Edtf Cessation Properties Edtf Inception  \
# 0                  3/2/2020                      uuuu
# 1                  3/2/2020                      uuuu
# 2                  3/2/2020                      uuuu
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88532 entries, 0 to 88531
# Data columns (total 17 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Geometry Coordinates 0 0               88532 non-null  float64
#  1   Geometry Coordinates 0 1               88532 non-null  float64
#  2   Geometry Coordinates 1 0               88532 non-null  float64
#  3   Geometry Coordinates 1 1               88532 non-null  float64
#  4   Geometry Type                          88532 non-null  object
#  5   Properties Edtf Cessation              88532 non-null  object
#  6   Properties Edtf Inception              88532 non-null  object
#  7   Properties Flysfo Actual Timestamp     88532 non-null  int64
#  8   Properties Flysfo Airline              88532 non-null  object
#  9   Properties Flysfo Base Airline         54864 non-null  object
# ...

# %%
data.describe()
# Out:
#        Geometry Coordinates 0 0  Geometry Coordinates 0 1  \
# count              88532.000000              88532.000000
# mean                -106.533160                 37.006403
# std                   42.653081                  7.918635
# min                 -159.347789                -37.668253
# 25%                 -122.370943                 36.081003
# 50%                 -122.370943                 37.617990
# 75%                 -111.980566                 38.685533
# max                  177.376360                 64.822005
#
#        Geometry Coordinates 1 0  Geometry Coordinates 1 1  \
# count              88532.000000              88532.000000
# mean                -106.956081                 36.980280
# std                   41.988356                  7.706460
# min                 -159.347789                -37.668253
# 25%                 -122.370943                 37.453966
# 50%                 -122.370943                 37.617990
# ...

# %%
data.describe().T
# Out:
#                                          count          mean            std  \
# Geometry Coordinates 0 0               88532.0 -1.065332e+02      42.653081
# Geometry Coordinates 0 1               88532.0  3.700640e+01       7.918635
# Geometry Coordinates 1 0               88532.0 -1.069561e+02      41.988356
# Geometry Coordinates 1 1               88532.0  3.698028e+01       7.706460
# Properties Flysfo Actual Timestamp     88532.0  1.584309e+09  748857.526766
# Properties Flysfo Base Flight Number   54864.0  2.093570e+03    1898.696397
# Properties Flysfo Estimated Timestamp  88532.0  1.584309e+09  748449.755323
#
#                                                 min           25%  \
# Geometry Coordinates 0 0              -1.593478e+02 -1.223709e+02
# Geometry Coordinates 0 1              -3.766825e+01  3.608100e+01
# Geometry Coordinates 1 0              -1.593478e+02 -1.223709e+02
# Geometry Coordinates 1 1              -3.766825e+01  3.745397e+01
# ...

# %%
data.corr()
# Out:
#                                        Geometry Coordinates 0 0  \
# Geometry Coordinates 0 0                               1.000000
# Geometry Coordinates 0 1                              -0.348441
# Geometry Coordinates 1 0                              -0.136320
# Geometry Coordinates 1 1                               0.030727
# Properties Flysfo Actual Timestamp                     0.017810
# Properties Flysfo Base Flight Number                  -0.206526
# Properties Flysfo Estimated Timestamp                  0.017752
#
#                                        Geometry Coordinates 0 1  \
# Geometry Coordinates 0 0                              -0.348441
# Geometry Coordinates 0 1                               1.000000
# Geometry Coordinates 1 0                               0.028355
# Geometry Coordinates 1 1                              -0.006391
# Properties Flysfo Actual Timestamp                    -0.007848
# Properties Flysfo Base Flight Number                   0.068675
# ...

# %%
data.isnull().any()
# Out:
# Geometry Coordinates 0 0                 False
# Geometry Coordinates 0 1                 False
# Geometry Coordinates 1 0                 False
# Geometry Coordinates 1 1                 False
# Geometry Type                            False
# Properties Edtf Cessation                False
# Properties Edtf Inception                False
# Properties Flysfo Actual Timestamp       False
# Properties Flysfo Airline                False
# Properties Flysfo Base Airline            True
# Properties Flysfo Base Flight Number      True
# Date                                     False
# Properties Flysfo Estimated Timestamp    False
# Properties Flysfo Event                  False
# Properties Flysfo Flight Number          False
# Properties Flysfo Gate                    True
# Route                                    False
# dtype: bool

# %%
data.columns
# Out:
# Index(['Geometry Coordinates 0 0', 'Geometry Coordinates 0 1',
#        'Geometry Coordinates 1 0', 'Geometry Coordinates 1 1', 'Geometry Type',
#        'Properties Edtf Cessation', 'Properties Edtf Inception',
#        'Properties Flysfo Actual Timestamp', 'Properties Flysfo Airline',
#        'Properties Flysfo Base Airline',
#        'Properties Flysfo Base Flight Number', 'Date',
#        'Properties Flysfo Estimated Timestamp', 'Properties Flysfo Event',
#        'Properties Flysfo Flight Number', 'Properties Flysfo Gate', 'Route'],
#       dtype='object')

# %%
data['Properties Flysfo Base Flight Number'].unique()
# Out:
# array([5628., 5233., 5318., ..., 3755., 1194.,  558.])

# %%
data['Properties Flysfo Base Flight Number']=data['Properties Flysfo Base Flight Number'].fillna(data['Properties Flysfo Base Flight Number'].median())

# %%
data['Properties Flysfo Base Flight Number'].isnull().sum()
# Out:
# 0

# %%
new_data=data.drop(['Geometry Type','Properties Edtf Inception','Properties Flysfo Airline','Properties Flysfo Base Airline','Date',
                          'Properties Flysfo Event', 'Properties Flysfo Flight Number', 'Properties Flysfo Gate', 'Route'],axis=1)
new_data
# Out:
#        Geometry Coordinates 0 0  Geometry Coordinates 0 1  \
# 0                   -122.370943                  37.61799
# 1                   -122.370943                  37.61799
# 2                   -122.370943                  37.61799
# 3                   -122.370943                  37.61799
# 4                   -122.370943                  37.61799
# ...                         ...                       ...
# 88527               -122.370943                  37.61799
# 88528               -122.370943                  37.61799
# 88529               -122.370943                  37.61799
# 88530               -122.370943                  37.61799
# 88531               -122.370943                  37.61799
#
#        Geometry Coordinates 1 0  Geometry Coordinates 1 1  \
# 0                   -118.353322                 34.196704
# 1                   -118.353322                 34.196704
# 2                   -118.353322                 34.196704
# ...

# %%
new_data['estimated_time']=pd.to_datetime(new_data['Properties Flysfo Estimated Timestamp'],unit='s')
new_data
# Out:
#        Geometry Coordinates 0 0  Geometry Coordinates 0 1  \
# 0                   -122.370943                  37.61799
# 1                   -122.370943                  37.61799
# 2                   -122.370943                  37.61799
# 3                   -122.370943                  37.61799
# 4                   -122.370943                  37.61799
# ...                         ...                       ...
# 88527               -122.370943                  37.61799
# 88528               -122.370943                  37.61799
# 88529               -122.370943                  37.61799
# 88530               -122.370943                  37.61799
# 88531               -122.370943                  37.61799
#
#        Geometry Coordinates 1 0  Geometry Coordinates 1 1  \
# 0                   -118.353322                 34.196704
# 1                   -118.353322                 34.196704
# 2                   -118.353322                 34.196704
# ...

# %%
new_data=new_data.drop(['Properties Edtf Cessation','Properties Flysfo Estimated Timestamp'],axis=1)
new_data
# Out:
#        Geometry Coordinates 0 0  Geometry Coordinates 0 1  \
# 0                   -122.370943                  37.61799
# 1                   -122.370943                  37.61799
# 2                   -122.370943                  37.61799
# 3                   -122.370943                  37.61799
# 4                   -122.370943                  37.61799
# ...                         ...                       ...
# 88527               -122.370943                  37.61799
# 88528               -122.370943                  37.61799
# 88529               -122.370943                  37.61799
# 88530               -122.370943                  37.61799
# 88531               -122.370943                  37.61799
#
#        Geometry Coordinates 1 0  Geometry Coordinates 1 1  \
# 0                   -118.353322                 34.196704
# 1                   -118.353322                 34.196704
# 2                   -118.353322                 34.196704
# ...

# %%
new_data['actual_time']=pd.to_datetime(new_data['Properties Flysfo Actual Timestamp'],unit='s')
new_data
# Out:
#        Geometry Coordinates 0 0  Geometry Coordinates 0 1  \
# 0                   -122.370943                  37.61799
# 1                   -122.370943                  37.61799
# 2                   -122.370943                  37.61799
# 3                   -122.370943                  37.61799
# 4                   -122.370943                  37.61799
# ...                         ...                       ...
# 88527               -122.370943                  37.61799
# 88528               -122.370943                  37.61799
# 88529               -122.370943                  37.61799
# 88530               -122.370943                  37.61799
# 88531               -122.370943                  37.61799
#
#        Geometry Coordinates 1 0  Geometry Coordinates 1 1  \
# 0                   -118.353322                 34.196704
# 1                   -118.353322                 34.196704
# 2                   -118.353322                 34.196704
# ...

# %%
new_data=new_data.drop(['Properties Flysfo Actual Timestamp'],axis=1)
new_data
# Out:
#        Geometry Coordinates 0 0  Geometry Coordinates 0 1  \
# 0                   -122.370943                  37.61799
# 1                   -122.370943                  37.61799
# 2                   -122.370943                  37.61799
# 3                   -122.370943                  37.61799
# 4                   -122.370943                  37.61799
# ...                         ...                       ...
# 88527               -122.370943                  37.61799
# 88528               -122.370943                  37.61799
# 88529               -122.370943                  37.61799
# 88530               -122.370943                  37.61799
# 88531               -122.370943                  37.61799
#
#        Geometry Coordinates 1 0  Geometry Coordinates 1 1  \
# 0                   -118.353322                 34.196704
# 1                   -118.353322                 34.196704
# 2                   -118.353322                 34.196704
# ...

# %%
X=new_data.drop(['estimated_time','actual_time'],axis=1)
y=new_data['estimated_time']

# %%
X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.4,random_state=80)

# %%
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
test_data=new_data.drop(['estimated_time','actual_time'],axis=1)

test_data
# Out:
#        Geometry Coordinates 0 0  Geometry Coordinates 0 1  \
# 0                   -122.370943                  37.61799
# 1                   -122.370943                  37.61799
# 2                   -122.370943                  37.61799
# 3                   -122.370943                  37.61799
# 4                   -122.370943                  37.61799
# ...                         ...                       ...
# 88527               -122.370943                  37.61799
# 88528               -122.370943                  37.61799
# 88529               -122.370943                  37.61799
# 88530               -122.370943                  37.61799
# 88531               -122.370943                  37.61799
#
#        Geometry Coordinates 1 0  Geometry Coordinates 1 1  \
# 0                   -118.353322                 34.196704
# 1                   -118.353322                 34.196704
# 2                   -118.353322                 34.196704
# ...

# %%
predictions=model.predict(test_data)

# %%
y['estimated_time']=predictions
# Out:
# C:\Users\samsung\AppData\Local\Temp/ipykernel_5228/561313885.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y['estimated_time']=predictions

# %%
y
# Out:
# 0                                               2020-03-02 18:42:00
# 1                                               2020-03-03 02:13:00
# 2                                               2020-03-03 00:32:00
# 3                                               2020-03-02 15:44:00
# 4                                               2020-03-02 22:19:00
#                                         ...
# 88528                                           2020-03-03 06:32:00
# 88529                                           2020-03-02 17:43:00
# 88530                                           2020-03-03 01:02:00
# 88531                                           2020-03-03 04:17:00
# estimated_time    [1.584316005518049e+18, 1.584315147040131e+18,...
# Name: estimated_time, Length: 88533, dtype: object

# %%
accuracy=model.score(x,predictions)
print(accuracy*100,'%')
# Out:
# 100.0 %
